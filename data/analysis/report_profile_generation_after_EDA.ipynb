# %% [markdown]
# # NOTE: Open files in /resources/after_eda_analysis_reports/* in the browser to see the generated reports

# %% [markdown]
# # Installing ydata-profiling to see the reports

# %%
# !pip install ydata-profiling
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.5/357.5 kB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.8/395.8 kB 11.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 11.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.5/679.5 kB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 13.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 20.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 27.8 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=59672f753351c7ed770321279347ce7f39e38cb876b03a9ee9f3e9661332fe80
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# ...
#   Attempting uninstall: typing-extensions
# ...

# %% [markdown]
# # Importing requried modules

# %%
import os
import pandas as pd
import numpy as np
from pandas_profiling import ProfileReport
from google.colab import drive
# Out:
# <ipython-input-2-2f8adcba22a2>:4: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport

# %% [markdown]
# # Mounting google drive onto colab instance

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Generating report for train.csv

# %%
drive_path = "/content/drive/MyDrive"
dataset_path = f"{drive_path}/town-data"

eda_reports_path = f"{drive_path}/EDA Reports"

# %%
train_clean_df = pd.read_csv(f"{dataset_path}/train_clean.csv")
train_profile = ProfileReport(train_clean_df)
train_profile.to_file(f"{dataset_path}/train_clean_report_after_EDA.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
